# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %%
df=pd.read_csv("D:\\data\\insurance_data.csv")
df.head()
# Out:
#    age  affordability  bought_insurance
# 0   22              1                 0
# 1   25              0                 0
# 2   47              1                 1
# 3   52              0                 0
# 4   46              1                 1

# %%
df.shape
# Out:
# (27, 3)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.iloc[:,:-1],df.bought_insurance,test_size=.2,random_state=None)

# %%
len(X_train)
# Out:
# 21

# %%
len(X_test)
# Out:
# 6

# %%
X_train_scaled=X_train.copy()
X_train_scaled['age']=X_train_scaled['age']/100
X_test_scaled=X_test.copy()
X_test_scaled['age']=X_test_scaled['age']/100

# %%
X_train_scaled.head()
# Out:
#      age  affordability
# 18  0.19              0
# 5   0.56              1
# 24  0.50              1
# 9   0.61              1
# 12  0.27              0

# %%
model=keras.Sequential([
    keras.layers.Dense(1,input_shape=(2,),activation='sigmoid',kernel_initializer='one',bias_initializer='zeros')
])##weight=0ne and bias=zero
model.compile(optimizer='adam',
             loss='binary_crossentropy',
             metrics=['accuracy'])
model.fit(X_train_scaled,y_train,epochs=5000)
# Out:
# Epoch 1/5000
# 1/1 [==============================] - 2s 2s/step - loss: 0.7710 - accuracy: 0.4286
# Epoch 2/5000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7705 - accuracy: 0.4286
# Epoch 3/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7700 - accuracy: 0.4286
# Epoch 4/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7695 - accuracy: 0.4286
# Epoch 5/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7689 - accuracy: 0.4286
# Epoch 6/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7684 - accuracy: 0.4286
# Epoch 7/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7679 - accuracy: 0.4286
# Epoch 8/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7674 - accuracy: 0.4286
# Epoch 9/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7669 - accuracy: 0.4286
# Epoch 10/5000
# ...

# %%
model.evaluate(X_test_scaled,y_test)
# Out:
# 1/1 [==============================] - 0s 323ms/step - loss: 0.5900 - accuracy: 0.8333
# [0.5900245308876038, 0.8333333134651184]

# %%
model.predict(X_test_scaled)
# Out:
# array([[0.75679475],
#        [0.6647607 ],
#        [0.8154254 ],
#        [0.69736546],
#        [0.11451557],
#        [0.11451557]], dtype=float32)

# %%
y_test
# Out:
# 15    1
# 4     1
# 8     1
# 14    1
# 16    1
# 1     0
# Name: bought_insurance, dtype: int64

# %%
X_test
# Out:
#     age  affordability
# 15   55              1
# 4    46              1
# 8    62              1
# 14   49              1
# 16   25              0
# 1    25              0

# %%
coef,intercept=model.get_weights()
coef,intercept# w1=[5.6301622] w2=[1.407263 ] and bias=[-3.0154107]
# Out:
# (array([[5.006711 ],
#         [1.6785972]], dtype=float32),
#  array([-3.2971017], dtype=float32))

# %% [markdown]
# # Making ourown defining function and checking with tensorflow

# %%
def sigmoid(x):
    import math
    return 1/(1+math.exp(-x))
sigmoid(18)
# Out:
# 0.9999999847700205

# %%
def prediction_fuction(age,affordibility):
    weighted_sum=coef[0]*age +coef[1]*affordibility+ intercept
    return sigmoid(weighted_sum)

# %%
prediction_fuction(.29,0)
# Out:
# 0.13644268942218418

# %%
def loggy_loss(y_true,y_predict):
    epsilon=1e-15
    y_predicted_new=[max(i,epsilon)for i in y_predict]
    y_predicted_new=[min(i,1-epsilon)for i in y_predicted_new]
    y_predicted_new=np.array(y_predicted_new)
    return -np.mean(y_true*np.log(y_predicted_new)+(1-y_true)*np.log(1-y_predicted_new))

# %%
def sigmoid_numpy(x):
    return 1/(1+np.exp(-x))
sigmoid_numpy(np.array([12,0,1]))
# Out:
# array([0.99999386, 0.5       , 0.73105858])

# %%
age=.21

# %%
y_predic=model.predict(X_test_scaled)
y_predic
# Out:
# array([[0.75679475],
#        [0.6647607 ],
#        [0.8154254 ],
#        [0.69736546],
#        [0.11451557],
#        [0.11451557]], dtype=float32)

# %%
def gradient_descent(age,affordability,y_true,epoch,loss_threshold):
    #w1,w2,bias
    w1=w2=1
    bias=0
    rate=.5
    n=len(age)
    for i in range(epoch):
        weighted_sum=w1*age+w2*affordability+bias
        y_predicted=sigmoid_numpy(weighted_sum)
        loss=loggy_loss(y_true,y_predicted)
        w1d=(1/n)*np.dot(np.transpose(age),(y_predicted-y_true))
        wkd=(1/n)*np.dot(np.array(age),(y_predicted-y_true))
        w2d=(1/n)*np.dot(np.transpose(affordability),(y_predicted-y_true))
        bias_d=np.mean(y_predicted-y_true)
        w1=w1-(rate*w1d)
        w2=w2-(rate*w2d)
        bias=bias-bias_d
        print(f'epoch:{i},w1:{w1},w2:{w2},bias:{bias},loss:{loss}')
        
        if loss<=loss_threshold:
            break
    return w1,w2,bias

# %%
gradient_descent(X_train_scaled['age'],X_train_scaled['affordability'],y_train,1000,0.3409)
# Out:
# epoch:0,w1:0.9690669005196868,w2:0.9241958422841335,bias:-0.3019903445456797,loss:0.7709966573834599
# epoch:1,w1:0.9517309762766781,w2:0.8715519861121502,bias:-0.5320377037025804,loss:0.6790989632956309
# epoch:2,w1:0.9457834434682255,w2:0.8390383619962132,bias:-0.702243009235948,loss:0.6280642714141309
# epoch:3,w1:0.9484620630598436,w2:0.8220604472135207,bias:-0.8273121058020253,loss:0.6012798239344049
# epoch:4,w1:0.9573045480321851,w2:0.8162459798733553,bias:-0.9201752585828664,loss:0.5872284686994664
# epoch:5,w1:0.9704229149222279,w2:0.8181389777528735,bias:-0.9906656503171193,loss:0.5794261209568615
# epoch:6,w1:0.986466690281656,w2:0.8252279326772333,bias:-1.0457799053126553,loss:0.5745997324397867
# epoch:7,w1:1.0044994608286595,w2:0.8357566416907158,bias:-1.0903526320691228,loss:0.5711811943184782
# epoch:8,w1:1.0238804653478903,w2:0.8485186152906867,bias:-1.1276844484963837,loss:0.5684360441237468
# ...

# %%
coef,intercept
# Out:
# (array([[5.006711 ],
#         [1.6785972]], dtype=float32),
#  array([-3.2971017], dtype=float32))

# %% [markdown]
# # Making ourown NNcustum model for testing with tensorflow

# %%
class myNN:
    def __init__(self):
        self.w1=1
        self.w2=1
        self.bias=0
    def fit(self,X,y,epoch,loss_thresold):
        self.w1,self.w2,self.bias=self.gradient_descent(X['age'],X['affordability'],y,epoch,loss_thresold)
    def predict(self,X_test):
        weighted_sum=self.w1* X_test['age']+self.w2*X_test['affordability']+self.bias
        return sigmoid_numpy(weighted_sum)
    def gradient_descent(self,age,affordability,y_true,epoch,loss_threshold):
        #w1,w2,bias
        w1=w2=1
        bias=0
        rate=.5
        n=len(age)
        for i in range(epoch):
            weighted_sum=w1*age+w2*affordability+bias
            y_predicted=sigmoid_numpy(weighted_sum)
            loss=loggy_loss(y_true,y_predicted)
            w1d=(1/n)*np.dot(np.transpose(age),(y_predicted-y_true))
            wkd=(1/n)*np.dot(np.array(age),(y_predicted-y_true))
            w2d=(1/n)*np.dot(np.transpose(affordability),(y_predicted-y_true))
            bias_d=np.mean(y_predicted-y_true)
            w1=w1-(rate*w1d)
            w2=w2-(rate*w2d)
            bias=bias-bias_d
            
            if i%50==0: ##only prnting at 50th epoch
                print(f'epoch:{i},w1:{w1},w2:{w2},bias:{bias},loss:{loss}')
            if loss<=loss_threshold:
                print(f'epoch:{i},w1:{w1},w2:{w2},bias:{bias},loss:{loss}')
                
                break
        return w1,w2,bias

# %%
cust_model=myNN()
cust_model.fit(X_train_scaled,y_train,epoch=5000,loss_thresold=0.3409)
# Out:
# epoch:0,w1:0.9690669005196868,w2:0.9241958422841335,bias:-0.3019903445456797,loss:0.7709966573834599
# epoch:50,w1:1.935157771784002,w2:1.364509170132069,bias:-1.9238235562027766,loss:0.4992090225256828
# epoch:100,w1:2.9574894899244804,w2:1.6701032752238134,bias:-2.566179379148707,loss:0.4449208860994155
# epoch:150,w1:3.8915092689892385,w2:1.843321786356549,bias:-3.070926594332135,loss:0.4035221017457121
# epoch:200,w1:4.740467221418309,w2:1.96519644774983,bias:-3.5015544323405816,loss:0.3702568591252429
# epoch:250,w1:5.512916318881604,w2:2.066186853476592,bias:-3.8855724033938888,loss:0.3429350590260468
# epoch:255,w1:5.5863242319269935,w2:2.075685660403404,bias:-3.921995776094288,loss:0.3404714722667467

# %%
cust_model.predict(X_test_scaled)
# Out:
# 15    0.773147
# 4     0.673355
# 8     0.834410
# 14    0.709094
# 16    0.074096
# 1     0.074096
# dtype: float64

# %%
coef,intercept ### almost same as tensorflow model
# Out:
# (array([[5.006711 ],
#         [1.6785972]], dtype=float32),
#  array([-3.2971017], dtype=float32))

# %%
model.predict(X_t)
